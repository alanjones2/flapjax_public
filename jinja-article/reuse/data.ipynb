# %%
import pandas as pd

df = pd.read_csv('countries_df.csv')
df
# Out:
#             Entity Code  Year  Annual CO₂ emissions  \
# 0      Afghanistan  AFG  1850                   NaN
# 1      Afghanistan  AFG  1851                   NaN
# 2      Afghanistan  AFG  1852                   NaN
# 3      Afghanistan  AFG  1853                   NaN
# 4      Afghanistan  AFG  1854                   NaN
# ...            ...  ...   ...                   ...
# 37424     Zimbabwe  ZWE  2017             9596071.0
# 37425     Zimbabwe  ZWE  2018            11795478.0
# 37426     Zimbabwe  ZWE  2019            11114607.0
# 37427     Zimbabwe  ZWE  2020            10607897.0
# 37428     Zimbabwe  ZWE  2021            11296114.0
#
#        Annual CO₂ emissions including land-use change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...
